# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
os.chdir('/Users/davidmiles-skov/Desktop/special_courses/materials_characterization/xrd_analysis/AutoXRD') # change working directory to root folder

# %%
# utils
from utils.grid_handlers import measurement_grid
from utils.data_loaders import read_XRD
from utils.plotting import plot_grid, plot_data

# %% [markdown]
# Taking a look at Anat's data

# %%
# NOTE: Taking some code from 'intern-data-handling'
# Not 100% sure what all of this is doing

grid = measurement_grid(5,5,34,34,-17,3) # BR_map 3mm margin (back sample)

# Load from path

path = 'data/anait_0016_Ba_all.txt'
initial_data, coords = read_XRD(path, grid, n = 100, separator = "\t")
plot_grid(coords,grid)

# %%
datatype_y= 'Intensity (counts)'
datatype_x='2θ (°)'
plot_data(initial_data, datatype_x, datatype_y , plotscale = 'log')
display(initial_data)
# Out:
# /Users/davidmiles-skov/Desktop/special_courses/materials_characterization/xrd_analysis/AutoXRD/utils/plotting.py:83: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# Coordinate -17.0,3.0                                                      \
# Data type     2θ (°) Intensity (counts) 2θ (°) Intensity (counts) 2θ (°)
# 0              15.00           409.0166  15.00           430.3639  15.00
# 1              15.01           407.6708  15.01           425.1343  15.01
# 2              15.02           406.1328  15.02           419.1576  15.02
# 3              15.03           405.5370  15.03           413.7518  15.03
# 4              15.04           408.5557  15.04           410.5355  15.04
# ...              ...                ...    ...                ...    ...
# 6996             NaN                NaN    NaN                NaN    NaN
# 6997             NaN                NaN    NaN                NaN    NaN
# 6998             NaN                NaN    NaN                NaN    NaN
# 6999             NaN                NaN    NaN                NaN    NaN
# 7000             NaN                NaN    NaN                NaN    NaN
#
# Coordinate                    -8.5,3.0                    0.0,3.0  \
# Data type  Intensity (counts)   2θ (°) Intensity (counts)  2θ (°)
# 0                    405.7600    15.00           434.4987   15.00
# 1                    408.4317    15.01           426.0880   15.01
# 2                    411.4851    15.02           416.4758   15.02
# 3                    414.6375    15.03           410.0671   15.03
# 4                    418.1695    15.04           415.9465   15.04
# ...                       ...      ...                ...     ...
# 6996                      NaN      NaN                NaN     NaN
# 6997                      NaN      NaN                NaN     NaN
# 6998                      NaN      NaN                NaN     NaN
# 6999                      NaN      NaN                NaN     NaN
# 7000                      NaN      NaN                NaN     NaN
#
# Coordinate                     ... 17.0,3.0                            \
# Data type  Intensity (counts)  ...   2θ (°) Intensity (counts) 2θ (°)
# 0                    637.6808  ...    10.00          480.33050  10.00
# 1                    646.2551  ...    10.01          481.17730  10.01
# 2                    656.0541  ...    10.02          482.14520  10.02
# 3                    663.5275  ...    10.03          482.72400  10.03
# 4                    662.0798  ...    10.04          481.80930  10.04
# ...                       ...  ...      ...                ...    ...
# 6996                      NaN  ...    79.96           61.25308  79.96
# 6997                      NaN  ...    79.97           60.36829  79.97
# 6998                      NaN  ...    79.98           58.67449  79.98
# 6999                      NaN  ...    79.99           55.37407  79.99
# 7000                      NaN  ...    80.00           52.02975  80.00
#
# Coordinate                    0.0,3.0                    8.5,3.0  \
# Data type  Intensity (counts)  2θ (°) Intensity (counts)  2θ (°)
# 0                   840.83470   10.00          464.09440   10.00
# 1                   838.86690   10.01          458.51330   10.01
# 2                   836.61800   10.02          452.13480   10.02
# 3                   834.75520   10.03          448.92940   10.03
# 4                   834.37510   10.04          457.90670   10.04
# ...                       ...     ...                ...     ...
# 6996                 56.90712   79.96           52.27859   79.96
# 6997                 56.93681   79.97           49.21198   79.97
# 6998                 57.21001   79.98           47.98425   79.98
# 6999                 57.96679   79.99           50.40839   79.99
# 7000                 58.73678   80.00           52.93231   80.00
#
# Coordinate                    17.0,3.0
# Data type  Intensity (counts)   2θ (°) Intensity (counts)
# 0                   454.79410    10.00          456.89450
# 1                   459.95650    10.01          463.04860
# 2                   465.85630    10.02          470.08190
# 3                   469.14760    10.03          474.75220
# 4                   462.42340    10.04          470.34980
# ...                       ...      ...                ...
# 6996                 53.42284    79.96           59.49016
# 6997                 51.04444    79.97           59.21165
# 6998                 50.54193    79.98           59.32579
# 6999                 53.76485    79.99           60.21973
# 7000                 57.08955    80.00           61.13497
#
# [7001 rows x 176 columns]
