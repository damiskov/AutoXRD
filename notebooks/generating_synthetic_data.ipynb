# %% [markdown]
# Checking out the synthetically generated data

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
os.chdir('/Users/davidmiles-skov/Desktop/special_courses/materials_characterization/xrd_analysis/AutoXRD') # change working directory to root folder

# %%
# load and plot npy file
interval = (0, 80)
x_vals = np.linspace(interval[0], interval[1], 1000)
data = np.load('data/synthetic_xrd_patterns.npy')
plt.figure(figsize=(10, 5))
plt.plot(x_vals,data.T[:, :10], alpha=0.5)
plt.xlabel('2-theta (degrees)')
plt.ylabel('Intensity (a.u.)')
plt.show()

# Inspect data shape
print(data.shape)
# Out:
# (1000, 1000)
